# %% [markdown]
# # MediChal Challenge - Detecting Malaria with cell Images
#
# ____

# %% [markdown]
# <img src="./logo.jpg" width="200" height="200" align="left">
#
# ## Team MEDICHAL :
# - Théo Deschamps-Berger
# - Simon Monteiro
# - Xienneng Xu
# - Nicolas Devatine
# - Clément Veyssière
# - Corentin Leloup
# - Ramine Hamidi

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Introduction </h2>
#     <p>
#         <br>
#
#
# The problem we try to solve here is the diagnosis of malaria using images of cells that are whether infected or not. It is a binary classification problem from the data set found here at <a href=https://www.kaggle.com/iarunava/cell-images-for-detecting-malaria>"Cell images for detecting malaria"</a>. The data set contains around 27 thousand images, that are balanced between the 2 classes. The way we proceed here is to extract features from the images instead of using images directly as inputs to the model we use for predictions.
#
#
# </div>

# %% [markdown]
# <p align="center">
#   <img src="example_cells.png">
# </p>
# <center>Example of parasitized and uninfected cells</center>

# %%
import sys
model_dir = 'sample_code_submission/'                        # Change the model to a better one once you have one!
result_dir = 'sample_result_submission/' 
problem_dir = 'ingestion_program/'  
score_dir = 'scoring_program/'
from sys import path; path.append(model_dir); path.append(problem_dir); path.append(score_dir); 
# %matplotlib inline
# Uncomment the next lines to auto-reload libraries (this causes some problem with pickles in Python 3)
# %load_ext autoreload
# %autoreload 2
import seaborn as sns; sns.set()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h1> Step 1: Exploratory data analysis </h1>
# <p>
# We provide sample_data with the starting kit, but to prepare your submission, you must fetch the public_data from the challenge website and point to it.
#     <br>
#     <span style="color:red"> Just change the data name in the block below. In the rest of the section, replace the sample plots by anything you want. </span>
# </div>

# %% [markdown]
# ### Quality of the data
#
# Our data is composed of images that we preprocessed to extract features. Therefore we do not have any missing data in any feature because we created the features ourselves. There may be one artefact which is the fact that the background is black, and we may wonder if infected cells might be smaller (or the contrary), which would provide us darker images and a higher (or lower) average of gray

# %%
data_dir = '../malaria_input_data'              # Change this to the directory where you put the input data
data_name = 'malaria'
# !ls $data_dir* # Linux command
# !dir $data_dir # Windows command
# Out:
# malaria_feat.name    malaria_test.data	     malaria_valid.data
# malaria_label.name   malaria_train.data
# malaria_public.info  malaria_train.solution

# %% [markdown]
# For convenience, we load the data as a "pandas" data frame, so we can use "pandas" and "seaborn" built in functions to explore the data.

# %%
from data_io import read_as_df
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = read_as_df(data_dir  + '/' + data_name)                # The data are loaded as a Pandas Data Frame

nb_p=np.sum(data.target == 'parasitized')
nb_u=np.sum(data.target == 'uninfected')

p = pd.DataFrame({'labels':['parasitized', 'uninfected'],'number of cells': [nb_p, nb_u]})
ax = p.plot.bar(x='labels', y='number of cells', rot=0),
plt.text(-0.12, nb_p/2, nb_p , size=20, color='r'),
plt.text(0.9, nb_u/2, nb_u , size=20, color='g'),plt.title('Distribution of our cells images')
plt.show()
# Out:
# Reading ../malaria_input_data/malaria_train from AutoML format
# Number of examples = 16534
# Number of features = 19
#          Class
# 0   uninfected
# 1  parasitized
# Number of classes = 2

# %%
data.head()
# Out:
#    nb_black_pixels  var_color  mean_color  min_color  max_color  var_gray  \
# 0             4884   0.000000    0.948893   0.948893   0.948893  0.419515
# 1             4347   0.000311    0.907223   0.874799   0.927769  0.519111
# 2             4935   0.000033    0.972043   0.962162   0.985586  0.266897
# 3             6501   0.000017    0.955153   0.950617   0.959436  0.594517
# 4             3384   0.000189    0.870487   0.857143   0.911565  2.217611
#
#    mean_gray  min_gray  max_gray  nb_pixel_0.0_0.1  nb_pixel_0.1_0.2  \
# 0   0.636039  0.529412  0.764706                 0                 0
# 1   0.633702  0.400000  0.823529                 0                 0
# 2   0.641619  0.568627  0.737255                 0                 0
# 3   0.661221  0.301961  0.745098                 0                 0
# 4   0.471401  0.345098  0.780392                 0                 0
#
#    nb_pixel_0.2_0.3  nb_pixel_0.3_0.4  nb_pixel_0.4_0.5  nb_pixel_0.5_0.6  \
# ...

# %% [markdown]
# We have decided to reduce the dataset of images to a simpler dataset with only 19 features.
#
# `nb_black_pixels` counts pixels whose value is dark for gray_scale images, those around the cell in the image.
#
# `var_color` feature is simply the empirical variance of the values of the pixels for colored images.
#
# `mean_color` feature is simply the mean of the values of the pixels for colored images.
#
# `max_color` is the maximum value for colored images.
#
# `min_color` is the maximum value for colored images.
#
# `var_gray`, `mean_gray`, `max_gray` and `min_gray` are the same but for gray-scale images.
#
# `nb_pixel_i_j` is the number of pixels having their value (intensity : 0 = black | 1 = white) between i and j for gray-scale images.

# %%
data.describe()
# Out:
#        nb_black_pixels     var_color    mean_color     min_color  \
# count     16534.000000  16534.000000  16534.000000  16534.000000
# mean       5186.434861      0.000187      0.932538      0.915922
# std        2555.612474      0.000685      0.042827      0.050649
# min         720.000000      0.000000      0.361582      0.308397
# 25%        3753.000000      0.000028      0.912136      0.892857
# 50%        4641.000000      0.000070      0.942715      0.926871
# 75%        5848.500000      0.000161      0.963064      0.950949
# max       79306.000000      0.030410      1.000000      1.000000
#
#           max_color      var_gray     mean_gray      min_gray      max_gray  \
# count  16534.000000  16534.000000  16534.000000  16534.000000  16534.000000
# mean       0.951003      0.455423      0.638756      0.425941      0.767492
# std        0.038777      0.401030      0.047318      0.166523      0.034910
# ...

# %% [markdown]
# Histogram of our features:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,16))

for t in range(19):
    plt.subplot(4,5,t+1)
    plt.hist(data[data.columns[t]])
    plt.title(data.columns[t])
    t+=1

# %% [markdown]
# Let's try to indentify patterns with a pairplot, which will maybe give us structures for each class depending on 2 features.

# %%
sns.pairplot(data[['target','nb_black_pixels','var_color','mean_color','min_color','max_color','var_gray','mean_gray','min_gray','max_gray']], hue="target")

# %% [markdown]
# Correlation of our features with the target: 'parasitized'

# %%
datatarget = pd.get_dummies(data['target'])['parasitized'].to_frame()
new_df = pd.merge(data, datatarget, right_index=True, left_index=True)
df_new = new_df.select_dtypes(include=np.number)

plt.figure(figsize = (10, 8))
ax = sns.heatmap(df_new.corr(),cmap="viridis", xticklabels=True, yticklabels=True)

d=pd.get_dummies(data['target'])['parasitized']

n_df = pd.merge(d.to_frame(), data, right_index=True, left_index=True)
df_n = n_df.select_dtypes(include=np.number).abs()


plt.figure(figsize = (2, 8))
ax = sns.heatmap(df_n.corr().abs().sort_values(['parasitized'], ascending=[0])["parasitized"].to_frame(), cmap="viridis", xticklabels=True, yticklabels=True)

# %%
boxplot = data.boxplot(column=['nb_black_pixels'], by='target', )

# %% [markdown]
# There seem to have no correlation between the number of black pixels and the target as well, then there is no dataleakage.

# %% [markdown]
# From the correlation matrix, the feature that has the highest correlation with the target is "min_gray".

# %%
boxplot = data.boxplot(column=['min_gray'], by='target', )

# %% [markdown]
# ## Model and results analysis
#
# Here we run a sandbox test to introduce some metrics and ways to visualize results. We split the train set into train and test in order to perform these analysis, and we compute the confusion matrix for RandomForestClassifier with arbitrary hyper-parameters.

# %%
from sklearn.model_selection import train_test_split
from data_manager import DataManager
from model import model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import ParameterGrid

D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)

# Load model
clf = RandomForestClassifier(random_state = 42, n_estimators = 2, max_depth = 5)
M = model() # The model is by default a random forest classifier

if not(M.is_trained):
    M.fit(X_train_pre, y_train_pre)                     

Y_hat_test_pre = M.predict(X_test_pre)

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test_pre, Y_hat_test_pre)
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# FIT: dim(X)= [11077, 19]
# FIT: dim(y)= [11077, 1]
# PREDICT: dim(X)= [5457, 19]
# PREDICT: dim(y)= [5457, 1]
# array([[2570,  105],
#        [ 158, 2624]])

# %% [markdown]
# This is the plot of the confusion matrix from the predictions performed.

# %%
ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test_pre, Y_hat_test_pre), annot=True, fmt='g', ax=ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Parasitized', 'Uninfected']);
ax.yaxis.set_ticklabels(['Parasitized', 'Uninfected']);
plt.show()

# %%
from sklearn.metrics import classification_report

target_names = ['Parasitized', 'Uninfected']
print(classification_report(y_test_pre, Y_hat_test_pre, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#  Parasitized       0.94      0.96      0.95      2675
#   Uninfected       0.96      0.94      0.95      2782
#
#     accuracy                           0.95      5457
#    macro avg       0.95      0.95      0.95      5457
# weighted avg       0.95      0.95      0.95      5457

# %% [markdown]
# Then we can compute the AUC metric which is the one used for the submission.

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Training a predictive model</h2>
#     <p>
# We provide an example of predictive model (for classification or regression) in the `sample_code_submission/` directory. It is a quite stupid model: it makes constant predictions. Replace it with your own model.
#     </div>

# %%
from data_io import write
from model import model
# Uncomment the next line to show the code of the model
#??model

# %% [markdown]
# <div style="background:#FFFFAA">
# an instance of the model (run the constructor) and attempt to reload a previously saved version from `sample_code_submission/`:
#
# </div>

# %% [markdown]
# <div style="background:#FFFFAA">
# <h1>Step 2: Building a predictive model</h1>
# </div>

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Loading data with DataManager</h2>
#     <p>
# We reload the data with the AutoML DataManager class because this is more convenient:
#    <br>     <span style="color:red"> Keep this, it illustrates how data in AutoML formal are loaded by the ingestion program </span>
# </div>

# %%
from data_manager import DataManager
D = DataManager(data_name, data_dir, replace_missing=True)
print(D)
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# DataManager : malaria
# info:
# 	usage = Malaria cell images dataset
# 	name = malaria
# 	task = binary.classification
# 	target_type = Numerical
# 	feat_type = Numerical
# 	metric = roc_auc_score
# 	time_budget = 1200
# 	feat_num = 19
# 	target_num = 2
# 	label_num = 2
# 	train_num = 16534
# 	valid_num = 5512
# 	test_num = 5512
# 	has_categorical = 0
# 	has_missing = 0
# 	is_sparse = 0
# 	format = dense
# data:
# 	X_train = array(16534, 19)
# 	Y_train = array(16534,)
# 	X_valid = array(5512, 19)
# 	Y_valid = array(0,)
# 	X_test = array(5512, 19)
# 	Y_test = array(0,)
# feat_type:	array(19,)
# feat_idx:	array(0,)

# %%
#Trying a random forest model
M = model()   #The model is by default a random forest classifier
trained_model_name = model_dir + data_name
# Uncomment the next line to re-load an already trained model
#M = M.load(trained_model_name)

# %% [markdown]
# <div style="background:#FFFFAA">
#     Train the model (unless you reloaded a trained model) and make predictions.
# </div>

# %%
if not(M.is_trained):
    X_train = D.data['X_train']
    Y_train = D.data['Y_train']
    M.fit(X_train, Y_train)                     

Y_hat_train = M.predict(D.data['X_train']) # Optional, not really needed to test on taining examples
Y_hat_valid = M.predict(D.data['X_valid'])
Y_hat_test = M.predict(D.data['X_test'])
# Out:
# FIT: dim(X)= [16534, 19]
# FIT: dim(y)= [16534, 1]
# PREDICT: dim(X)= [16534, 19]
# PREDICT: dim(y)= [16534, 1]
# PREDICT: dim(X)= [5512, 19]
# PREDICT: dim(y)= [5512, 1]
# PREDICT: dim(X)= [5512, 19]
# PREDICT: dim(y)= [5512, 1]

# %% [markdown]
# <div style="background:#FFFFAA">
#     <b> Save the trained model </b> (will be ready to reload next time around) and save the prediction results. IMPORTANT: if you save the trained model, it will be bundled with your sample code submission. Therefore your model will NOT be retrained on the challenge platform. Remove the pickle from the submission if you want the model to be retrained on the platform.
# </div>

# %%
M.save(trained_model_name)                 
result_name = result_dir + data_name
from data_io import write
write(result_name + '_train.predict', Y_hat_train)
write(result_name + '_valid.predict', Y_hat_valid)
write(result_name + '_test.predict', Y_hat_test)
# !ls $result_name*
# Out:
# sample_result_submission/malaria_test.predict
# sample_result_submission/malaria_train.predict
# sample_result_submission/malaria_valid.predict

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Scoring the results</h2>
#     <h3>Load the challenge metric</h3>
#     <p>
# <b>The metric chosen for your challenge</b> is identified in the "metric.txt" file found in the `scoring_function/` directory. The function "get_metric" searches first for a metric having that name in my_metric.py, then in libscores.py, then in sklearn.metric.
#     </div>

# %% [markdown]
# We use the area under the curve as our metric to evaluate our model for the moment. We chose this metric because accuracy gives us only the percentage of correctly classified examples, whereas what we are interested in is to have the lowest possible rate of false negatives (infected cells classifies as being healthy). The ROC curve we will get will help us to find a good threshold for this classification, which will not necessarily the one maximising the accuracy as the false negatives are critical in our case (but the true negatives can always be rechecked by experts). The AUC will then give us the general performance of our model given the fact that we want to maximize true positives and true negatives.

# %%
from libscores import get_metric
metric_name, scoring_function = get_metric()
print('Using scoring metric:', metric_name)
# Uncomment the next line to display the code of the scoring metric
#??scoring_function
# Out:
# Using scoring metric: roc_auc_score

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h3> Training performance </h3>
#     <p>
# The participants normally posess target values (labels) only for training examples (except for the sample data). We compute with the `example` metric the training score, which should be zero for perfect predictions.
#         </div>

# %%
print('Training score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_train, Y_hat_train))
print('Ideal score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_train, Y_train))
# Out:
# Training score for the roc_auc_score metric = 0.9958
# Ideal score for the roc_auc_score metric = 1.0000

# %% [markdown]
# You can add here other scores and result visualization.

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_train, Y_hat_train)
# Out:
# array([[8252,    6],
#        [  64, 8212]])

# %%
from sklearn.metrics import roc_curve, auc

size = round(len(D.data['X_train'])/10)

probas_ = M.classifier.fit(D.data['X_train'][:size], D.data['Y_train'][:size].ravel()).predict_proba(D.data['X_train'][size:])
# Compute ROC curve and area the curve
fpr, tpr, thresholds = roc_curve(D.data['Y_train'][size:].ravel(), probas_[:, 1])
roc_auc = auc(fpr, tpr)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 7))

plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# This plot of the ROC curve is a good indicator for us to find a good threshold for our model, here we will prefer a very low rate of false negatives (1 - true positives rate). If we really want something near to 100% true positives, we might consider a model giving us 40% of false positive rate, we might consider that threshold as a medical diagnosis is a critical application.

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h3>Cross-validation performance</h3>
#     <p>
# The participants do not have access to the labels Y_valid and Y_test to self-assess their validation and test performances. But training performance is not a good prediction of validation or test performance. Using cross-validation, the training data is split into multiple training/test folds, which allows participants to self-assess their model during development. The average CV result and 95% confidence interval is displayed.
#    </div>

# %%
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
M= model ()
scores = cross_val_score(M, X_train, Y_train, cv=5, scoring=make_scorer(scoring_function))
print('\nCV score (95 perc. CI): %0.2f (+/- %0.2f)' % (scores.mean(), scores.std() * 2))
scores
# Out:
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13228, 19]
# FIT: dim(y)= [13228, 1]
# PREDICT: dim(X)= [3306, 19]
# PREDICT: dim(y)= [3306, 1]
#
# CV score (95 perc. CI): 0.95 (+/- 0.01)
# array([0.9536122 , 0.95384373, 0.94671811, 0.95639702, 0.95031821])

# %%
"""
data2 = data.drop(['nb_black_pixels'], axis=1)
X_train2 = data2.drop(['target'], axis= 1)
X_train2
M = model()
scores = cross_val_score(M, X_train2, Y_train, cv=5, scoring=make_scorer(scoring_function))
print('\nCV score without the black_pixels attribute (95 perc. CI): %0.2f (+/- %0.2f)' % (scores.mean(), scores.std() * 2))
scores
"""
# Out:
# "\ndata2 = data.drop(['nb_black_pixels'], axis=1)\nX_train2 = data2.drop(['target'], axis= 1)\nX_train2\nM = model()\nscores = cross_val_score(M, X_train2, Y_train, cv=5, scoring=make_scorer(scoring_function))\nprint('\nCV score without the black_pixels attribute (95 perc. CI): %0.2f (+/- %0.2f)' % (scores.mean(), scores.std() * 2))\nscores\n"

# %% [markdown]
# The scores of our model with and without the nb_black_pixels attribute is the same. Therefore we can conclude that there is no data leakage.

# %% [markdown]
# ____

# %% [markdown]
# ### Feature importance

# %% [markdown]
# The advantage of using a Random forest models is that we can evaluate which feature in taken into account  when predicting the target classes, here you can have an idea of which feature was the most relevant for solving our task

# %%
data.shape
# Out:
# (16534, 20)

# %%
import pandas as pd

feature_importance = pd.DataFrame(M.classifier.feature_importances_,index= list(data)[:19], columns=['feature importance']).sort_values('feature importance', ascending = False)
feature_importance.plot.bar(figsize=(9,7))
plt.show()

# %% [markdown]
# <div style="background:#FFFFAA">
# <h1> Step 3: Making a submission </h1>
#
# <h2> Unit testing </h2>
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. All you have to do to make a submission is modify the file <code>model.py</code> in the <code>sample_code_submission/</code> directory, then run this test to make sure everything works fine. This is the actual program that will be run on the server to test your submission.
# <br>
# Keep the sample code simple.
# </div>

# %%
# !source activate python3.7; python $problem_dir/ingestion.py $data_dir $result_dir $problem_dir $model_dir
# Out:
# /bin/sh: 1: source: not found
# Using input_dir: /home/alexandre/Info232/MOSQUITO/malaria_input_data
# Using output_dir: /home/alexandre/Info232/MOSQUITO/starting_kit/sample_result_submission
# Using program_dir: /home/alexandre/Info232/MOSQUITO/starting_kit/ingestion_program
# Using submission_dir: /home/alexandre/Info232/MOSQUITO/starting_kit/sample_code_submission
#
# ========== Ingestion program version 6 ==========
#
# ************************************************
# ******** Processing dataset Malaria ********
# ************************************************
# ========= Reading and converting data ==========
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# ========= Reading /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_feat.type
# [+] Success in  0.00 sec
# ========= Reading /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_train.data
# Replace missing values by 0 (slow, sorry)
# [+] Success in  0.14 sec
# ...

# %% [markdown]
# <div style="background:#FFFFAA">
# Also test the scoring program:
#     </div>

# %%
scoring_output_dir = 'scoring_output'
# !python $score_dir/score.py $data_dir $result_dir $scoring_output_dir
# Out:
# ======= Set 1 (Malaria_train): roc_auc_score(set1_score)=0.995770113689 =======

# %% [markdown]
# ## Parameter optimization to try to improve the area under the roc curve.

# %%
from sklearn.model_selection import ParameterGrid
from sklearn.ensemble import RandomForestClassifier

# import os
# import sys
# sys.stdout = open(os.devnull, 'w')

# Define the hyperparameters
hyperparameters = {
    'max_depth': [5, 10, 20,40], 
    'n_estimators' : [2,10, 20, 100] }

# Compute all combinations
parameter_grid = list(ParameterGrid(hyperparameters))

# Just a table to save the results
#resultsDF = pd.DataFrame(columns=['factors', 'regularization', 'alpha', 'auc'])
resultsDF = pd.DataFrame()

for parameter_combination in parameter_grid:    
    clf = RandomForestClassifier (random_state = 42, n_estimators =parameter_combination['n_estimators'],max_depth =parameter_combination['max_depth'])
    M = model (classifier=clf)
    
    
    scores = cross_val_score(M, X_train, Y_train, cv=5, scoring=make_scorer(scoring_function))
    
    
    parameter_combination['auc'] = scores.mean()
    
    resultsDF = resultsDF.append(parameter_combination, ignore_index=True)
    
res = resultsDF.sort_values(by=['auc'], ascending=False)
# Out:
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13228, 19]
# FIT: dim(y)= [13228, 1]
# PREDICT: dim(X)= [3306, 19]
# PREDICT: dim(y)= [3306, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# PREDICT: dim(y)= [3307, 1]
# FIT: dim(X)= [13227, 19]
# FIT: dim(y)= [13227, 1]
# PREDICT: dim(X)= [3307, 19]
# ...

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h1> Preparing the submission </h1>
#
# Zip the contents of `sample_code_submission/` (without the directory), or download the challenge public_data and run the command in the previous cell, after replacing sample_data by public_data.
# Then zip the contents of `sample_result_submission/` (without the directory).
# <b><span style="color:red">Do NOT zip the data with your submissions</span></b>.
# </div>

# %%
import datetime 
from data_io import zipdir

the_date = datetime.datetime.now().strftime("%y-%m-%d-%H-%M")
sample_code_submission = '../sample_code_submission_' + the_date + '.zip'
sample_result_submission = '../sample_result_submission_' + the_date + '.zip'
zipdir(sample_code_submission, model_dir)
zipdir(sample_result_submission, result_dir)
print("Submit one of these files:\n" + sample_code_submission + "\n" + sample_result_submission)
# Out:
# Submit one of these files:
# ../sample_code_submission_20-03-01-14-58.zip
# ../sample_result_submission_20-03-01-14-58.zip

# %% [markdown]
# # Détection de "outlier" ou Cas particulier
#
# Voir [ici](https://scikit-learn.org/stable/modules/outlier_detection.html#id1), je vais utiliser la deuxième solution proposé: IsolationForest.
#
# L'exemple utilisé pour le code: [ici](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html#sklearn.ensemble.IsolationForest)
#
# Les raisons sont:
# * Les données ne sont peut-être pas uniforme
# * Grand? nombre de paramètres (19 doit être relativement peu donc bon...)
# * Nous n'avons pas "de forme générale" de données

# %%
#Package utile
from sklearn.ensemble import IsolationForest

# %%
D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)

#Ici on entraine notre détecteur d'outlier
clf = IsolationForest(random_state=0).fit(X_train_pre)

#Ici on détermine si le même ensemble comporte des outliers, on détectera ici seulement
#les cas d'outlier très extrême car on fait l'apprentissage et le test sur le même ensemble
res = clf.predict(X_train_pre)
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %% [markdown]
# La méthode predict retourne un tuple avec $\pm$1 si le composant doit être considéré comme un cas normal ou particulier.

# %% [markdown]
# # Filtrage et suppression des outlier
#
# Avec la méthode predict, nous avons les outlier, si la i-ème composante de predict est égale à -1, alors la i-ème donnée dans l'ensemble est un outlier.
#
# Pour la suppression des outliers, j'ai préféré tous les supprimé d'un coup et non 1 à 1.

# %%
#Cette fonction affiche le % d'outlier dans X et retourne  un nouvel ensemble sans outlier, elle NE modifie PAS X
def supprOutlier(X,retIndex=False):
    clf = IsolationForest(random_state=0).fit(X_train_pre)
    res = clf.predict(X_train_pre)
    
    indexOutlier = []
    for i in range (0,len(res)):
        if res[i]==-1:
            indexOutlier.append(i)
    
    pourcentOutlier = len(indexOutlier) / len(res) * 100
    print("Pourcentage d'outlier: {0:.3f}%:".format(pourcentOutlier))
    
    if retIndex:
        return np.delete(X,indexOutlier,axis=0),indexOutelier
    
    #delete: Supprime les LIGNES d'indices dans indexOutlier
    return np.delete(X,indexOutlier,axis=0)

#Version supérieur de supprOutlier pour aussi affecter les labels
def supprOutlierV2(X,y,retIndex=False):
    clf = IsolationForest(random_state=0).fit(X_train_pre)
    res = clf.predict(X_train_pre)
    
    indexOutlier = []
    for i in range (0,len(res)):
        if res[i]==-1:
            indexOutlier.append(i)
    
    pourcentOutlier = len(indexOutlier) / len(res) * 100
    print("Pourcentage d'outlier: {0:.3f}%:".format(pourcentOutlier))
    
    if retIndex:
        return np.delete(X,indexOutlier,axis=0),np.delete(y,indexOutlier,axis=0),indexOutelier
    
    #delete: Supprime les LIGNES d'indices dans indexOutlier
    return np.delete(X,indexOutlier,axis=0),np.delete(y,indexOutlier,axis=0)

# %% [markdown]
# Il serait intéressant de visualiser les clusters de données avant/après suppressions des outliers.

# %%
D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info

# %%
X_train_pre = supprOutlier(X_train_pre)
# Out:
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Pourcentage d'outlier: 10.003%:

# %% [markdown]
# Nous allons voir si l'allure des clusters varient avant/suppression des outliers.

# %%
from sklearn.mixture import GaussianMixture
import matplotlib.patches as mpatches

D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)

X = X_train_pre

gauss = GaussianMixture(n_components = 2)
y_pred = gauss.fit_predict(X)

colors = np.array(['#0b559f', '#89bedc'])

cells_a = mpatches.Patch(color = colors[0], label='uninfected')
cells_b = mpatches.Patch(color = colors[1], label='parasitized')

fig,ax = plt.subplots(2,1,figsize=(15,12))



for a in ax:
    a.legend(handles=[cells_a,cells_b])

ax[0].scatter(X[:, 7], X[:, 8], c=colors[y_pred])
ax[0].set_title("Sans suppression d'outlier")

X = supprOutlier(X)

gauss = GaussianMixture(n_components = 2)
y_pred = gauss.fit_predict(X)
ax[1].scatter(X[:, 7], X[:, 8], c=colors[y_pred])
ax[1].set_title("Avec suppression d'outlier")
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Pourcentage d'outlier: 10.003%:
# Text(0.5, 1.0, "Avec suppression d'outlier")

# %% [markdown]
# Les résultats varient beaucoup ici (apprentissage non supervisé) Mais en général:
# * On observe une meilleur séparation avec la détection d'outlier.

# %% [markdown]
# # Réduction de dimension à l'aide de [PCA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)
# Raisons:
# * Première proposée
# * TSNE conseille d'autres méthodes dont PCA pour certains cas
# * PCA a une méthode de score, peut-être utile?

# %%
#Package utile
from sklearn.decomposition import PCA

# %% [markdown]
# Il serait aussi intéressant de savoir si notre détection d'outlier change quelque chose.
#
# Je me suis beaucoup aidé d'[ici](https://stackoverflow.com/questions/43131274/how-do-i-plot-two-countplot-graphs-side-by-side-in-seaborn)
#
# On s'inspire du [TP2](https://github.com/PhamAlexT/info232/blob/master/TP2/TP2.ipynb)

# %%
#var_explained = np.round(pca.explained_variance_**2/np.sum(pca.explained_variance_ratio**2), decimals=3)

fig,ax = plt.subplots(1,2,figsize=(10,7))

#Données sans suppressions d'outlier
D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)
pca = PCA(n_components=19)
X = X_train_pre
pca.fit(X)
var_explained = pca.explained_variance_ratio_

#Plot pour les données d'en haut
sns.barplot(x=list(range(1,len(var_explained)+1)),
            y=var_explained, color="limegreen",ax=ax[0])

#Données après suppressions d'outlier
pca = PCA(n_components=19)
X = X_train_pre
X = supprOutlier(X) #C'est ici qu'on supprime les outliers
pca.fit(X)
var_explained = pca.explained_variance_ratio_

#Plot pour les données d'en haut
sns.barplot(x=list(range(1,len(var_explained)+1)),
            y=var_explained, color="limegreen",ax=ax[1])

ax[0].set_xlabel('SVs', fontsize=16)
ax[0].set_ylabel('Percent Variance Explained', fontsize=16)
ax[0].set_title("Avec outlier")

ax[1].set_xlabel('SVs', fontsize=16)
ax[1].set_ylabel('Percent Variance Explained', fontsize=16)
ax[1].set_title("Sans outlier")
#plt.savefig('svd_scree_plot.png',dpi=100)
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Pourcentage d'outlier: 10.003%:
# Text(0.5, 1.0, 'Sans outlier')

# %% [markdown]
# Nous voyons qu'avec suppression d'oulier puis PCA, nous pouvons nous ramener à 4 dimensions alors que sans la suppression d'outlier, nous pouvons nous ramener à 5 dimensions.
#
# Cela ne paraît pas si différent mais il ne faut pas oublier que nous sommes sur une petit échelle.
#
# On peut essayer de voir la différence de séparation de cluster avec ou sans suppression après une PCA.

# %%
#Reduire la dimension pour le plot 

d = df_n.drop(columns=['parasitized'])
pca = PCA(n_components=4).fit(d)
X_pcaAA = pca.transform(d)
l = df_n.to_numpy()[:,0]       #On recupere les vrais labels
plt.legend(handles=[cells_a,cells_b])
plt.title('PCA avec Outliers')
plt.scatter(X_pcaAA[:, 0], X_pcaAA[:, 1],  c=colors[l.astype(int)])

# %% [markdown]
# Ce n'est pas si satisfaisant, et si on essayait de supprimer les outliers?
#
# Ici: https://stackoverflow.com/questions/23199796/detect-and-exclude-outliers-in-pandas-data-frame ? (Pas utile ici...Aurait pu)

# %%
from scipy import stats

def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.05)
    q3 = df_in[col_name].quantile(0.95)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)

X = X_train_pre
Y = y_train_pre

X,Y = supprOutlierV2(X,Y)
pca = PCA(n_components=2).fit(X)
X_pcaSA = pca.transform(X)
plt.legend(handles=[cells_a,cells_b])
plt.title('PCA sans Outliers')
#print(y)
#print(colors)
#print(l)
l = []

for val in Y:
    l.append(val)
l = np.array(l)
plt.scatter(X_pcaSA[:, 0], X_pcaSA[:, 1],  c=colors[l.astype(int)])
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Pourcentage d'outlier: 10.003%:

# %% [markdown]
# Comparaison avec et sans outliers:

# %%
fig,ax = plt.subplots(1,2,figsize=(20,8))

l = df_n.to_numpy()[:,0] 
ax[0].scatter(X_pcaAA[:, 0], X_pcaAA[:, 1],  c=colors[l.astype(int)])

l = []

for val in Y:
    l.append(val)
l = np.array(l)
ax[1].scatter(X_pcaSA[:, 0], X_pcaSA[:, 1],  c=colors[l.astype(int)])


ax[0].set_title("Avec outlier")
ax[1].set_title("Sans outlier")
fig.suptitle("Comparaison PCA avec et sans outlier")
fig.legend(handles=[cells_a,cells_b])

# %% [markdown]
# Nous voyons une différence avec les axes. Sans outlier, nous sommes sur des intervalles de valeurs plus restreintes qu'avec.

# %% [markdown]
# # Réduction de dimensions à l'aide de TSNE
#
# Par le cours d'aujourd'hui, je sais que TSNE n'est pas pratique pour le processing, mais utile à la visualisation.
#
# Je voulais m'inspirer d'[ici](https://towardsdatascience.com/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b):

# %%
#Package utile
from sklearn.manifold import TSNE
import time

# %% [markdown]
# Trop couteuse à tester niveau temps...

# %% [markdown]
# # PCA puis TSNE pour une meilleur visualisation?

# %% [markdown]
# # Réduction de dimension à l'aide de TruncatedSVD
#
# Contrairement à PCA, les données ne sont pas centrées, il serait intéressant de voir le résultat avec PCA et les comparer.
# Nous allons comparer avec/sans outliers

# %%
from sklearn.decomposition import TruncatedSVD

#Données sans suppressions d'outlier
D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)
X = X_train_pre

svd = TruncatedSVD(n_components=18, n_iter=20, random_state=42)
svd.fit(X)
var_explained = svd.explained_variance_ratio_

fig,ax = plt.subplots(1,2,figsize=(10,7))
sns.barplot(x=list(range(1,len(var_explained)+1)),
            y=var_explained, color="limegreen",ax=ax[0])
#Sans
X = supprOutlier(X)
svd = TruncatedSVD(n_components=18, n_iter=20, random_state=42)
svd.fit(X)
var_explained = svd.explained_variance_ratio_

sns.barplot(x=list(range(1,len(var_explained)+1)),
            y=var_explained, color="limegreen",ax=ax[1])
ax[0].set_xlabel('SVs', fontsize=16)
ax[0].set_ylabel('Percent Variance Explained', fontsize=16)
ax[0].set_title("Avec outlier")

ax[1].set_xlabel('SVs', fontsize=16)
ax[1].set_ylabel('Percent Variance Explained', fontsize=16)
ax[1].set_title("Sans outlier")
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Pourcentage d'outlier: 10.003%:
# Text(0.5, 1.0, 'Sans outlier')

# %% [markdown]
# On obtient le même résultat qu'avec PCA cependant l'allure n'est pas la même.

# %%
#Reduire la dimension pour le plot 
d = df_n.drop(columns=['parasitized'])
tsvd= TruncatedSVD(n_components=2)
X_tsvdAA = tsvd.fit_transform(d)
l = df_n.to_numpy()[:,0]
plt.legend(handles=[cells_a,cells_b])
plt.title('TSVD avec ouliers')
plt.scatter(X_tsvdAA[:, 0], X_tsvdAA[:, 1],  c=colors[l.astype(int)])
plt.show()

# %% [markdown]
# Sans outlier:

# %%
D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)

X = X_train_pre
Y = y_train_pre

X,Y = supprOutlierV2(X,Y)
tsvd = TruncatedSVD(n_components=2).fit(X)
X_tsvdSA = tsvd.transform(X)
plt.legend(handles=[cells_a,cells_b])
plt.title('TSVD sans Outliers')
#print(y)
#print(colors)
#print(l)
l = []

for val in Y:
    l.append(val)
l = np.array(l)
plt.scatter(X_tsvdSA[:, 0], X_tsvdSA[:, 1],  c=colors[l.astype(int)])
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Pourcentage d'outlier: 10.003%:

# %% [markdown]
# Comparons TVSD avec et sans outlier

# %%
fig,ax = plt.subplots(1,2,figsize=(20,8))

l = df_n.to_numpy()[:,0] 
ax[0].scatter(X_tsvdAA[:, 0], X_tsvdAA[:, 1],  c=colors[l.astype(int)])

l = []

for val in Y:
    l.append(val)
l = np.array(l)
ax[1].scatter(X_tsvdSA[:, 0], X_tsvdSA[:, 1],  c=colors[l.astype(int)])


ax[0].set_title("Avec outlier")
ax[1].set_title("Sans outlier")
fig.suptitle("Comparaison PCA avec et sans outlier")
fig.legend(handles=[cells_a,cells_b])

# %% [markdown]
# Même conclusion qu'avant

# %% [markdown]
# # Comparaison PCA et TSNE
#
# Il est intéressant de comparer avec outlier avec TSVD et PCA et sans outlier pour les 2

# %%
l = df_n.to_numpy()[:,0] 
fig,ax = plt.subplots(1,2,figsize=(20,8))

ax[0].scatter(X_pcaAA[:, 0], X_pcaAA[:, 1],  c=colors[l.astype(int)])
ax[1].scatter(X_tsvdAA[:, 0], X_tsvdAA[:, 1],  c=colors[l.astype(int)])

ax[0].set_title("PCA")
ax[1].set_title("TSVD")

fig.suptitle("Avec outlier")
fig.legend(handles=[cells_a,cells_b])
l = []

for val in Y:
    l.append(val)
l = np.array(l)
fig1,ax1 = plt.subplots(1,2,figsize=(20,8))

ax1[0].scatter(X_pcaSA[:, 0], X_pcaSA[:, 1],  c=colors[l.astype(int)])
ax1[1].scatter(X_tsvdSA[:, 0], X_tsvdSA[:, 1],  c=colors[l.astype(int)])

ax1[0].set_title("PCA")
ax1[1].set_title("TSVD")

fig1.suptitle("Sans outlier")
fig1.legend(handles=[cells_a,cells_b])

# %% [markdown]
# Graphiquement, voici des mesures approchés:
#
# Avec outlier:
# * Distance entre le x min et x max:
#     * PCA:40 000
#     * TVSD:60 000
# * Distance entre le y min et y max:
#     * PCA: 50 000
#     * TVSD: 60 000
#
# Avec outlier, nous voyons bien la différence que fait si nous centrons les données ou non.
#
# Sans outlier:
# * Distance entre le x min et x max:
#     * PCA:25 000
#     * TVSD:30 000
# * Distance entre le y min et y max:
#     * PCA: 25 000
#     * TVSD: 20 000
#
# Sans outlier, la différence est beaucoup moins importante avec les 2 méthodes.

# %% [markdown]
# # Sélection de features
#
# Avec ce qui a été fait [avant](http://localhost:8888/notebooks/starting_kit/README_preprocessing.ipynb#Quality-of-the-data), on sait que la feature "nb_black_pixels est inutile".
# Aussi, en faisant attention aux tableaux donné par describe() et head() que des données ne varient pas.
#
# Nous pouvons les supprimés directement avec un drop() mais utilisons ce qui a été donné ici: https://scikit-learn.org/stable/modules/feature_selection.html.
# Plus précisément:
# * [Variance](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.VarianceThreshold.html)
# * [Tree-based feature selection](https://scikit-learn.org/stable/modules/feature_selection.html#tree-based-feature-selection)

# %%
#Package utile
from sklearn.feature_selection import VarianceThreshold

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectFromModel

# %%
D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)

#Nous allons travaillé avec un ensemble dépourvu d'outlier (pour pas que cela soit "inutile")
X = supprOutlier(X_train_pre)
#X = X_train_pre
nbL1 = np.shape(X)[0]
#Ici on supprime les données qui varient de 0.5 sur tout leurs attributs
sel = VarianceThreshold(threshold=0.5)
"""
sel.fit(X)
X = sel.transform(X)
"""
X = sel.fit_transform(X)
nbL2 = np.shape(X)[0]
print("Nombres de données avant:{} \nNombre de données après:{}".format(nbL1,nbL2))
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Pourcentage d'outlier: 10.003%:
# Nombres de données avant:9969
# Nombre de données après:9969

# %%
D = DataManager(data_name, data_dir, replace_missing=True)
X_train_pre, X_test_pre, y_train_pre, y_test_pre = train_test_split(D.data['X_train'], D.data['Y_train'], test_size=0.33, random_state=42)

X,y = supprOutlierV2 (X_train_pre,y_train_pre)

#Nous commencons le travail
clf = ExtraTreesClassifier(n_estimators=50)
clf = clf.fit(X, y)
clf.feature_importances_

model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)

print(X_new.shape)
# Out:
# Info file found : /home/alexandre/Info232/MOSQUITO/malaria_input_data/malaria_public.info
# /home/alexandre/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:415: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Pourcentage d'outlier: 10.003%:
# (9969, 5)

# %% [markdown]
# On retrouve le 4 résultat d'[ici](http://localhost:8888/notebooks/starting_kit/README_preprocessing.ipynb#R%C3%A9duction-de-dimension-%C3%A0-l'aide-de-PCA)...
#
# Puis j'ai vu cela: https://thispointer.com/python-pandas-how-to-get-column-and-row-names-in-dataframe/

# %%
#Obtention des indices des classes:
indices = []
for i in range(0,len(model.get_support())):
    if model.get_support()[i]:
        indices.append(i)

#Dataframe avec le nom des features
data = read_as_df(data_dir  + '/' + data_name)

print("Voici les features sélectionnés:")
for i in indices:
    print(data.columns.values[i])
# Out:
# Reading ../malaria_input_data/malaria_train from AutoML format
# Number of examples = 16534
# Number of features = 19
#          Class
# 0   uninfected
# 1  parasitized
# Number of classes = 2
# Voici les features sélectionnés:
# var_gray
# min_gray
# nb_pixel_0.4_0.5
# nb_pixel_0.5_0.6
# nb_pixel_0.6_0.7

# %% [markdown]
# Nous retrouvons le résultat issu de PCA et TruncatedSVD.

# %% [markdown]
# Désolé pour les redondances dans le code, j'ai essayé de faire le plus propre.
